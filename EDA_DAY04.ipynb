# %% [markdown]
# ## 作業
# 在鐵達尼資料集中，
# 透過進階補值方法 KNN，將鐵達尼號中的 Titanic_train
# .csv 中的 age 的遺失值進行補值。
# * step1: 觀察 Age 和 Pclass 與 Sex 是否有關連性?
# * step2: 如果有關連性，運用 KNN ，取出 Age 、 Pclass、 Sex的資料，以 Sex 與 Pclass 補 Age 遺失值。

# %%
# import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display

# %% [markdown]
# ## 讀入資料

# %%
train=pd.read_csv('Titanic_train.csv')

# %% [markdown]
# ## 觀察 Age

# %%
origin=pd.DataFrame(train)
display(origin)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data=pd.DataFrame(train[train['Age'].isnull()])
display(data)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# ## 觀察 Age和Pclass是否有關連性

# %%
sns.regplot(x="Age", y="Pclass", color="g",data=origin)

#年紀越大船艙等級數字越小，表示艙位等級越高，因此有關連性
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pclass'>

# %% [markdown]
# ## 觀察 Age和Sex是否有關連性

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
origin['Sex']=le.fit_transform(origin['Sex'],)

sns.regplot(x="Age", y="Sex", color="g",data=origin)

#兩者間無關連性
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %% [markdown]
# ## 運用 KNN ， 取出Age 、 Pclass的資料，以Pclass 補 Age 遺失值。

# %%
data2=pd.DataFrame({
    'Age':origin['Age'],
    'Pclass':origin['Pclass']
})
data2
# Out:
#       Age  Pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %%
value_neighbors=3
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=value_neighbors)
df_filled = pd.DataFrame(imputer.fit_transform(data2))
display(df_filled)
# Out:
#              0    1
# 0    22.000000  3.0
# 1    38.000000  1.0
# 2    26.000000  3.0
# 3    35.000000  1.0
# 4    35.000000  3.0
# ..         ...  ...
# 886  27.000000  2.0
# 887  19.000000  1.0
# 888  27.666667  3.0
# 889  26.000000  1.0
# 890  32.000000  3.0
#
# [891 rows x 2 columns]

# %%
origin['Age']=df_filled[1]
print('共',origin['Age'].isnull().sum(),'個遺失值')
# Out:
# 共 0 個遺失值
